# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

#filename = maybe_download('text8.zip', 31344016)
filename = './text8.zip'

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'term', 'of', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.185877
# Nearest to his: dionysus, bhopal, autonomous, cayley, veyron, envoy, hun, rights,
# Nearest to he: cartwright, renn, tithe, antiochus, williams, scabbard, shorten, intercept,
# Nearest to more: reproach, exists, dolphins, behaving, graham, tuamotu, piles, visualization,
# Nearest to known: chang, differ, septimius, nominee, eidyn, marketable, immaterial, weimar,
# Nearest to nine: meanwhile, drivetrain, furtherance, overheat, abolitionists, christe, arterial, queensberry,
# Nearest to s: outage, polymorphism, mariana, evacuated, equip, pasting, lucretius, travolta,
# Nearest to often: dragoon, copyrights, inexplicable, aalto, eixample, opiates, castrati, unpredictability,
# Nearest to a: amaranth, openings, wove, dominican, hinders, nightmare, verify, stwa,
# Nearest to th: dru, swat, apocalyptic, unleavened, blister, equivalently, sloped, nitro,
# Nearest to four: screens, mestizos, marginalized, disloyalty, almohades, enemy, replacing, cuff,
# Nearest to such: daniell, reliever, lamborghini, paradoxical, verlag, tungsten, entrepreneurs, sarmatians,
# Nearest to about: racine, drinkers, monochromatic, completes, sasson, there, auditioning, eastwards,
# Nearest to system: neutral, phoenician, footprint, bag, alphanumeric, distributed, casein, river,
# Nearest to this: meritorious, badge, filing, lynched, unconfirmed, exceeding, curving, unintentionally,
# Nearest to in: atomic, eph, utensils, boredom, reachable, caine, landholdings, cools,
# Nearest to three: postcard, strived, philanthropist, clinched, cooley, saying, cuny, navy,
# Average loss at step 2000: 4.374342
# Average loss at step 4000: 3.863457
# Average loss at step 6000: 3.785196
# Average loss at step 8000: 3.689943
# Average loss at step 10000: 3.615329
# Nearest to his: their, the, her, its, s, mired, acoustics, revoke,
# Nearest to he: it, they, she, who, also, dundee, there, auchinleck,
# Nearest to more: exists, reproach, less, dolphins, behaving, expressing, graham, mengistu,
# Nearest to known: mithraea, differ, glide, breaker, unproductive, used, prose, eidyn,
# Nearest to nine: eight, six, seven, five, zero, three, four, two,
# Nearest to s: his, and, missourians, sinti, engrams, mutiny, recorder, deferred,
# Nearest to often: fishery, quite, mujahedin, personnel, cape, not, schneider, dragoon,
# Nearest to a: the, panth, australians, any, this, seeking, ely, z,
# Nearest to th: sloped, minicomputers, rd, blister, one, helen, declining, teleport,
# Nearest to four: six, three, five, eight, seven, two, zero, nine,
# Nearest to such: stare, reliever, pez, fence, lamborghini, trivalent, fooled, daniell,
# Nearest to about: only, drinkers, there, outweigh, westinghouse, trumbull, after, sedition,
# Nearest to system: neutral, phoenician, river, translate, ieung, most, adapting, whispers,
# Nearest to this: it, the, which, meritorious, that, a, kummer, grave,
# Nearest to in: of, on, from, with, by, at, and, into,
# Nearest to three: six, five, two, four, eight, seven, nine, zero,
# Average loss at step 12000: 3.606691
# Average loss at step 14000: 3.569600
# Average loss at step 16000: 3.410259
# Average loss at step 18000: 3.458263
# Average loss at step 20000: 3.538901
# Nearest to his: their, her, its, the, mired, acoustics, inhumane, beria,
# Nearest to he: it, she, they, who, there, originally, we, dundee,
# Nearest to more: less, most, expressing, very, exists, gracie, behaving, glass,
# Nearest to known: such, used, mithraea, far, stay, well, eidyn, differ,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to s: protruding, unconstitutional, dukes, missourians, mutiny, spake, longue, controls,
# Nearest to often: widely, quite, usually, also, who, they, sometimes, fishery,
# Nearest to a: the, this, another, any, portions, panth, seeking, sylia,
# Nearest to th: rd, sloped, helen, op, minicomputers, planckian, teleport, declining,
# Nearest to four: three, six, five, eight, seven, two, nine, zero,
# Nearest to such: known, many, well, reliever, fence, benthic, fooled, raids,
# Nearest to about: only, drinkers, outweigh, westinghouse, sasson, going, hundred, perfume,
# Nearest to system: neutral, phoenician, translate, river, whispers, most, ieung, reims,
# Nearest to this: which, it, a, the, another, pursue, poz, lira,
# Nearest to in: at, from, between, on, with, during, of, under,
# Nearest to three: four, six, five, seven, two, eight, nine, one,
# Average loss at step 22000: 3.506400
# Average loss at step 24000: 3.487043
# Average loss at step 26000: 3.484529
# Average loss at step 28000: 3.482709
# Average loss at step 30000: 3.504918
# Nearest to his: her, their, its, the, s, acoustics, slander, ejaculate,
# Nearest to he: it, she, they, who, there, we, delano, dundee,
# Nearest to more: less, most, expressing, very, exists, compelled, tp, formalize,
# Nearest to known: used, such, well, mithraea, described, far, eidyn, standardizing,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to s: his, missourians, diary, dpp, dirk, faq, macaulay, her,
# Nearest to often: usually, sometimes, widely, commonly, generally, simply, who, still,
# Nearest to a: panth, any, bookseller, sporadic, allegations, the, no, portions,
# Nearest to th: rd, six, sloped, op, nd, minicomputers, four, teleport,
# Nearest to four: three, five, six, seven, eight, two, nine, zero,
# Nearest to such: well, known, many, these, some, fence, benthic, townsfolk,
# Nearest to about: drinkers, entrepreneur, only, stem, outweigh, libertine, attackers, going,
# Nearest to system: neutral, translate, erode, phoenician, flasks, ieung, antipsychotic, impossibility,
# Nearest to this: which, it, that, lira, what, another, any, not,
# Nearest to in: under, during, at, of, on, and, between, with,
# Nearest to three: four, seven, five, eight, two, six, nine, zero,
# Average loss at step 32000: 3.505031
# Average loss at step 34000: 3.494631
# Average loss at step 36000: 3.456307
# Average loss at step 38000: 3.305980
# Average loss at step 40000: 3.428294
# Nearest to his: her, their, its, the, acoustics, s, my, beria,
# Nearest to he: she, it, they, there, who, i, originally, honorum,
# Nearest to more: less, most, very, hanssen, consigned, expressing, so, inexorably,
# Nearest to known: used, such, mithraea, described, standardizing, worldstatesmen, called, cfr,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to s: his, spake, missourians, reversing, dpp, stench, aggadah, diary,
# Nearest to often: usually, sometimes, widely, commonly, generally, which, also, who,
# Nearest to a: the, another, or, enzyte, portions, any, seeking, quartier,
# Nearest to th: rd, op, reviving, nd, minicomputers, eight, sloped, unleavened,
# Nearest to four: six, three, five, eight, seven, two, nine, one,
# Nearest to such: well, known, many, including, benthic, these, fence, fooled,
# Nearest to about: stem, libertine, attackers, postulating, pyle, entrepreneur, going, drinkers,
# Nearest to system: systems, neutral, flasks, translate, phoenician, exxon, tw, erode,
# Nearest to this: which, it, the, that, lira, bout, another, any,
# Nearest to in: of, on, from, during, at, and, for, to,
# Nearest to three: four, five, seven, six, two, eight, nine, one,
# Average loss at step 42000: 3.437302
# Average loss at step 44000: 3.451968
# Average loss at step 46000: 3.453916
# Average loss at step 48000: 3.355025
# Average loss at step 50000: 3.389350
# Nearest to his: her, their, its, the, your, my, incarcerated, acoustics,
# Nearest to he: she, it, they, who, there, never, ungulates, initially,
# Nearest to more: less, most, very, inexorably, hanssen, consigned, expressing, greater,
# Nearest to known: used, such, described, called, regarded, well, objectively, ticonderoga,
# Nearest to nine: eight, seven, six, four, three, five, zero, one,
# Nearest to s: spake, faq, his, midian, egyptians, glastonbury, whose, diary,
# Nearest to often: usually, sometimes, generally, commonly, widely, frequently, still, also,
# Nearest to a: another, the, sylia, panth, facilitation, spam, sporadic, bookseller,
# Nearest to th: rd, op, reviving, nd, episcopi, five, sloped, bc,
# Nearest to four: six, seven, three, eight, five, nine, two, zero,
# Nearest to such: known, well, these, many, certain, including, follows, benthic,
# Nearest to about: libertine, attackers, stem, syne, paralleled, entrepreneur, thrust, decorated,
# Nearest to system: systems, neutral, higham, footprint, translate, flasks, click, erode,
# Nearest to this: which, it, the, another, lira, that, holder, usually,
# Nearest to in: during, within, until, on, between, from, of, crawl,
# Nearest to three: six, four, seven, eight, nine, five, two, zero,
# Average loss at step 52000: 3.434197
# Average loss at step 54000: 3.426413
# Average loss at step 56000: 3.441061
# Average loss at step 58000: 3.396630
# Average loss at step 60000: 3.397330
# Nearest to his: her, their, its, my, incarcerated, your, the, beria,
# Nearest to he: she, it, they, who, there, originally, never, relatedness,
# Nearest to more: less, most, rather, very, hanssen, smaller, other, alerting,
# Nearest to known: used, such, well, regarded, defined, described, cfr, considered,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to s: spake, faq, although, engrams, finnic, fem, airwaves, his,
# Nearest to often: usually, sometimes, generally, commonly, frequently, widely, also, still,
# Nearest to a: the, any, another, facilitation, this, allegations, spam, panth,
# Nearest to th: rd, six, five, nd, op, seven, sloped, bc,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to such: well, known, these, many, including, manipulated, certain, some,
# Nearest to about: libertine, attackers, syne, stem, on, thrust, paralleled, sites,
# Nearest to system: systems, vigour, neutral, flasks, impossibility, erode, rickey, nih,
# Nearest to this: it, which, that, there, some, the, however, another,
# Nearest to in: during, within, until, of, since, at, between, including,
# Nearest to three: five, four, seven, six, eight, two, nine, one,
# Average loss at step 62000: 3.243937
# Average loss at step 64000: 3.259608
# Average loss at step 66000: 3.405646
# Average loss at step 68000: 3.394994
# Average loss at step 70000: 3.360847
# Nearest to his: her, their, its, my, your, cartwright, laurie, the,
# Nearest to he: she, it, they, who, there, never, we, originally,
# Nearest to more: less, most, very, smaller, extremely, larger, rather, too,
# Nearest to known: used, such, regarded, well, defined, described, responsible, called,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to s: spake, airframes, finnic, should, airwaves, tangible, reinforces, whose,
# Nearest to often: sometimes, usually, generally, commonly, widely, frequently, now, still,
# Nearest to a: the, another, any, macros, facilitation, sweetener, portions, quartier,
# Nearest to th: rd, nd, bc, op, third, episcopi, sloped, seven,
# Nearest to four: six, five, seven, three, eight, two, nine, zero,
# Nearest to such: these, well, known, many, some, regarded, certain, including,
# Nearest to about: libertine, syne, thrust, on, mactutor, attackers, sites, decorated,
# Nearest to system: systems, program, erode, neutral, flasks, vehicle, higham, bond,
# Nearest to this: it, which, the, another, that, there, some, usually,
# Nearest to in: within, until, during, on, at, through, from, since,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Average loss at step 72000: 3.374987
# Average loss at step 74000: 3.350868
# Average loss at step 76000: 3.327329
# Average loss at step 78000: 3.354580
# Average loss at step 80000: 3.373114
# Nearest to his: her, their, its, my, your, cartwright, the, beria,
# Nearest to he: she, it, they, who, there, never, we, originally,
# Nearest to more: less, most, very, smaller, extremely, highly, increasingly, rather,
# Nearest to known: used, defined, regarded, such, called, responsible, described, considered,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to s: faq, your, spake, gcb, chris, economist, sufficed, engrams,
# Nearest to often: usually, sometimes, generally, commonly, typically, frequently, widely, now,
# Nearest to a: another, the, sylia, amaranth, panth, every, thrown, sweetener,
# Nearest to th: rd, op, nd, episcopi, twentieth, third, sloped, bc,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to such: well, these, known, follows, certain, regarded, including, hubble,
# Nearest to about: syne, libertine, attackers, paralleled, over, decorated, mactutor, sites,
# Nearest to system: systems, program, footprint, higham, erode, duress, goodbye, vigour,
# Nearest to this: which, it, another, the, rabi, what, consultant, some,
# Nearest to in: within, during, until, on, at, of, under, around,
# Nearest to three: six, five, seven, four, two, eight, nine, one,
# Average loss at step 82000: 3.406871
# Average loss at step 84000: 3.409537
# Average loss at step 86000: 3.388002
# Average loss at step 88000: 3.353525
# Average loss at step 90000: 3.366901
# Nearest to his: her, their, its, your, my, our, beria, the,
# Nearest to he: she, they, it, there, originally, who, later, but,
# Nearest to more: less, most, very, extremely, increasingly, smaller, fairly, highly,
# Nearest to known: used, such, called, regarded, responsible, described, defined, seen,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to s: spake, hiragana, hawick, engrams, isbn, whose, abbott, faq,
# Nearest to often: usually, sometimes, generally, commonly, typically, frequently, also, now,
# Nearest to a: another, any, panth, thrown, the, every, expositor, dodi,
# Nearest to th: rd, seven, one, six, nd, episcopi, op, twentieth,
# Nearest to four: five, seven, six, eight, three, two, nine, one,
# Nearest to such: well, known, follows, regarded, these, many, certain, cited,
# Nearest to about: libertine, syne, decorated, frankenheimer, over, dundas, attackers, discernible,
# Nearest to system: systems, process, vigour, program, erode, legalised, geos, impossibility,
# Nearest to this: it, which, another, the, some, modal, any, there,
# Nearest to in: during, within, under, priory, abolishing, at, with, between,
# Nearest to three: two, five, four, seven, eight, six, nine, zero,
# Average loss at step 92000: 3.399943
# Average loss at step 94000: 3.254133
# Average loss at step 96000: 3.358258
# Average loss at step 98000: 3.246797
# Average loss at step 100000: 3.357282
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to he: she, it, they, there, who, we, never, subsequently,
# Nearest to more: less, most, very, increasingly, smaller, fairly, extremely, hanssen,
# Nearest to known: used, such, defined, described, responsible, seen, regarded, called,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to s: his, dpp, my, whose, spake, your, finnic, shatter,
# Nearest to often: usually, sometimes, generally, commonly, typically, frequently, now, widely,
# Nearest to a: another, any, the, panth, spaceflights, guillotined, sylia, portions,
# Nearest to th: rd, nd, third, bc, op, episcopi, twentieth, dhekelia,
# Nearest to four: seven, six, five, eight, three, nine, two, zero,
# Nearest to such: known, well, including, these, follows, many, regarded, hubble,
# Nearest to about: syne, libertine, on, reintroduce, outweigh, usury, decorated, smitten,
# Nearest to system: systems, program, process, neutral, erode, higham, geos, bond,
# Nearest to this: which, it, another, what, the, that, some, avro,
# Nearest to in: during, within, until, on, throughout, at, since, of,
# Nearest to three: four, five, six, seven, eight, two, nine, one,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  #assert num_skips <= 2 * skip_window
  
  batch = np.ndarray(shape=(batch_size, 2 * skip_window), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    target = skip_window  # target label at the center of the buffer
    batch[i] = np.delete(buffer, skip_window)
    labels[i, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.421388
# Nearest to more: terse, pinnacle, boz, dementia, profession, hennecke, antinomies, vendors,
# Nearest to people: buffy, rebellion, housing, abel, calves, fux, integrates, ridley,
# Nearest to there: gotland, resolution, twitch, contributors, drinking, mejid, anthony, lighten,
# Nearest to system: broadcasted, conqueror, congresses, fabric, dx, buckingham, flaubert, loses,
# Nearest to over: haq, brick, operator, rolland, harnack, tropes, womanhood, acutely,
# Nearest to i: jus, reliever, gegen, wreckin, ingrained, clouded, diagnosing, fluoxetine,
# Nearest to as: hue, declare, vibrate, binds, pohnpei, arica, magick, mocking,
# Nearest to also: wtoo, mann, rare, communism, cpr, uterus, starbucks, kingfishers,
# Nearest to so: purgatory, precaution, general, thirds, lived, birmingham, toes, thorough,
# Nearest to american: coco, mobilizing, expeditionary, smith, homeric, pointy, apolitical, megatokyo,
# Nearest to of: wasteland, valid, apartheid, progesterone, chesterton, reims, dumpster, woensel,
# Nearest to its: sharman, brittle, lesions, deviant, vint, archaically, wellesley, sanity,
# Nearest to their: presheaf, gretchen, roma, euskal, mutate, ararat, flirted, sola,
# Nearest to it: gradual, brainiac, edema, lounge, unification, prompted, dish, sides,
# Nearest to nine: select, solicit, truk, shugart, keywords, pops, liang, incorruptible,
# Nearest to when: speller, shimazu, clustering, isbn, chickenpox, spies, plate, recalled,
# Average loss at step 2000: 4.097938
# Average loss at step 4000: 3.559322
# Average loss at step 6000: 3.381303
# Average loss at step 8000: 3.240787
# Average loss at step 10000: 3.172526
# Nearest to more: most, less, terse, minerva, rather, jacobsen, pickup, stack,
# Nearest to people: buffy, names, astrologers, overtly, knighted, fux, rebellion, valuable,
# Nearest to there: it, they, illegitimacy, often, dial, meg, bulky, anthony,
# Nearest to system: trackball, congresses, eunuch, anoint, flaubert, fabric, conqueror, alligators,
# Nearest to over: tropes, wandering, operator, through, philosophiae, acutely, rolland, proceedings,
# Nearest to i: gegen, breaching, you, iii, sailboat, milieu, replenish, ductile,
# Nearest to as: tonnage, repression, stockings, theresa, midst, projected, silenced, generator,
# Nearest to also: often, which, sometimes, wtoo, rare, not, marvellous, masefield,
# Nearest to so: lived, toes, updating, gerardus, anders, bounty, heretics, salinas,
# Nearest to american: polish, vdp, english, mobilizing, fermions, prose, coco, rijeka,
# Nearest to of: containing, in, ritchie, twilight, tentacles, wasteland, buoyant, gamete,
# Nearest to its: their, his, the, her, lesions, hq, enhances, wellesley,
# Nearest to their: its, his, her, the, giants, wracked, brodie, him,
# Nearest to it: he, there, this, she, often, they, which, always,
# Nearest to nine: eight, six, seven, five, four, zero, three, two,
# Nearest to when: if, shimazu, deposit, enjoyable, rs, modularity, recalled, ios,
# Average loss at step 12000: 3.205996
# Average loss at step 14000: 3.154484
# Average loss at step 16000: 3.180744
# Average loss at step 18000: 3.119416
# Average loss at step 20000: 2.986260
# Nearest to more: less, most, very, rather, jacobsen, highly, rambla, pinker,
# Nearest to people: buffy, names, critics, astrologers, seasons, distant, scotch, citizens,
# Nearest to there: they, it, illegitimacy, he, often, which, madox, still,
# Nearest to system: systems, alligators, trackball, paralipomena, lillian, gif, paralleling, congresses,
# Nearest to over: through, rolland, operator, brassiere, regarding, replace, wandering, inductance,
# Nearest to i: you, we, gegen, iii, ii, t, he, g,
# Nearest to as: theresa, scottie, projected, specializations, stockings, angiotensin, when, striping,
# Nearest to also: often, sometimes, still, which, wtoo, now, masefield, never,
# Nearest to so: initio, salinas, bmi, niro, disposal, takes, more, anders,
# Nearest to american: english, polish, portuguese, militare, australian, withdraws, supporting, arab,
# Nearest to of: in, for, roundhouse, wasteland, daylights, clears, hoarding, containing,
# Nearest to its: their, his, her, the, legnica, warmth, lesions, enhances,
# Nearest to their: its, his, her, the, our, your, my, wracked,
# Nearest to it: he, she, there, this, they, officially, deport, which,
# Nearest to nine: eight, seven, six, five, zero, four, three, two,
# Nearest to when: if, after, before, within, where, modularity, though, fittest,
# Average loss at step 22000: 3.074948
# Average loss at step 24000: 3.032050
# Average loss at step 26000: 2.999087
# Average loss at step 28000: 3.028558
# Average loss at step 30000: 3.003186
# Nearest to more: less, very, most, rather, highly, greater, fleece, higher,
# Nearest to people: men, critics, individuals, members, seasons, players, names, buffy,
# Nearest to there: they, it, he, often, idioms, now, she, jia,
# Nearest to system: systems, alligators, paralipomena, trackball, keystone, centrality, gif, byelorussian,
# Nearest to over: through, regarding, around, about, replace, inductance, photographic, within,
# Nearest to i: you, we, gegen, ii, g, genotype, iii, seward,
# Nearest to as: repression, generator, vindhya, zetalisp, specializations, tonnage, indie, reinforcing,
# Nearest to also: often, now, sometimes, still, which, usually, here, never,
# Nearest to so: bmi, too, workable, parti, niro, commonality, counterfeiting, hotline,
# Nearest to american: australian, british, polish, english, offsets, italian, german, supporting,
# Nearest to of: in, matsui, wasteland, cbm, including, lysergic, shaky, mesogens,
# Nearest to its: their, his, her, the, our, stealthy, legnica, modernist,
# Nearest to their: its, his, her, our, the, these, kylie, my,
# Nearest to it: he, she, this, there, they, deport, officially, still,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to when: if, after, before, though, where, while, during, guarneri,
# Average loss at step 32000: 2.828069
# Average loss at step 34000: 2.959485
# Average loss at step 36000: 2.943278
# Average loss at step 38000: 2.942892
# Average loss at step 40000: 2.933776
# Nearest to more: less, very, most, rather, highly, higher, greater, larger,
# Nearest to people: men, individuals, names, citizens, members, buffy, animals, those,
# Nearest to there: they, it, he, she, often, now, sometimes, still,
# Nearest to system: systems, alligators, gif, process, circumnavigate, memory, hammerhead, trackball,
# Nearest to over: through, regarding, within, off, before, around, inductance, replace,
# Nearest to i: we, g, UNK, you, gegen, ii, t, they,
# Nearest to as: stockings, hue, quantified, indie, after, paranormal, theresa, striping,
# Nearest to also: now, often, sometimes, still, usually, which, below, here,
# Nearest to so: too, bmi, workable, initio, niro, commonality, jannaeus, takes,
# Nearest to american: australian, italian, british, irish, polish, french, dutch, german,
# Nearest to of: grenadines, including, loo, capsules, shaky, afars, although, curie,
# Nearest to its: their, his, her, the, your, our, simeon, conifer,
# Nearest to their: its, his, her, the, your, my, our, whose,
# Nearest to it: he, she, there, this, they, still, god, officially,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to when: if, before, after, though, where, while, during, although,
# Average loss at step 42000: 2.949300
# Average loss at step 44000: 2.959344
# Average loss at step 46000: 2.904289
# Average loss at step 48000: 2.869796
# Average loss at step 50000: 2.844539
# Nearest to more: less, most, rather, very, highly, larger, higher, smaller,
# Nearest to people: men, individuals, citizens, children, women, jews, animals, members,
# Nearest to there: they, it, he, she, now, we, often, sometimes,
# Nearest to system: systems, process, alligators, circumnavigate, hammerhead, technology, radiant, trackball,
# Nearest to over: off, through, within, regarding, dom, around, plummer, out,
# Nearest to i: we, you, g, ii, iv, mail, gegen, seward,
# Nearest to as: trolling, theresa, like, mustaine, xt, how, minimalistic, adopts,
# Nearest to also: now, sometimes, often, still, actually, usually, which, below,
# Nearest to so: too, bmi, rial, thus, niro, initio, lusatia, tp,
# Nearest to american: british, australian, polish, german, italian, irish, esque, english,
# Nearest to of: including, gamete, lysergic, daylights, wasteland, although, advises, during,
# Nearest to its: their, his, her, the, our, your, whose, clerical,
# Nearest to their: its, his, her, our, your, my, whose, the,
# Nearest to it: he, she, there, this, they, balanchine, which, officially,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to when: if, before, after, while, though, where, during, although,
# Average loss at step 52000: 2.886787
# Average loss at step 54000: 2.864093
# Average loss at step 56000: 2.853696
# Average loss at step 58000: 2.751999
# Average loss at step 60000: 2.833347
# Nearest to more: less, most, rather, highly, larger, greater, poker, faster,
# Nearest to people: men, individuals, citizens, women, children, immigrants, jews, person,
# Nearest to there: they, it, she, he, still, often, cretian, we,
# Nearest to system: systems, process, technology, alligators, unit, thinkpad, company, circumnavigate,
# Nearest to over: regarding, within, through, dom, mcgrath, between, around, afesd,
# Nearest to i: you, we, g, ii, ned, mathrm, iv, typewriters,
# Nearest to as: theresa, how, xt, like, paranormal, scottie, rowers, trolling,
# Nearest to also: sometimes, now, often, still, usually, actually, which, never,
# Nearest to so: too, thus, bmi, sometimes, parti, rial, niro, initio,
# Nearest to american: australian, italian, british, polish, offsets, german, irish, english,
# Nearest to of: including, although, clears, grenadines, include, during, gamete, wasteland,
# Nearest to its: their, his, her, the, our, your, whose, stealthy,
# Nearest to their: its, his, her, our, your, my, the, whose,
# Nearest to it: he, she, this, there, officially, itself, they, which,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to when: if, after, though, where, before, during, although, while,
# Average loss at step 62000: 2.834153
# Average loss at step 64000: 2.777248
# Average loss at step 66000: 2.767425
# Average loss at step 68000: 2.715583
# Average loss at step 70000: 2.778825
# Nearest to more: less, most, highly, very, greater, rather, larger, longer,
# Nearest to people: men, women, individuals, citizens, children, jews, person, immigrants,
# Nearest to there: it, they, he, she, now, still, sometimes, we,
# Nearest to system: systems, process, company, alligators, technology, unit, guth, paralipomena,
# Nearest to over: within, regarding, dom, mcgrath, across, through, about, afesd,
# Nearest to i: we, you, ii, iii, dawkins, g, iv, ru,
# Nearest to as: xt, barclay, theresa, adopts, plectrum, after, including, accumulator,
# Nearest to also: now, sometimes, actually, never, often, usually, then, still,
# Nearest to so: too, thus, rial, temporally, tp, sometimes, bmi, niro,
# Nearest to american: australian, british, polish, german, irish, italian, english, canadian,
# Nearest to of: in, including, lysergic, gamete, geostationary, meade, during, although,
# Nearest to its: their, his, the, her, whose, your, convenience, hq,
# Nearest to their: its, his, her, your, our, my, whose, the,
# Nearest to it: she, he, there, this, they, officially, itself, often,
# Nearest to nine: eight, seven, five, six, four, three, zero, two,
# Nearest to when: if, after, while, though, before, although, during, where,
# Average loss at step 72000: 2.794268
# Average loss at step 74000: 2.645349
# Average loss at step 76000: 2.797305
# Average loss at step 78000: 2.824147
# Average loss at step 80000: 2.777186
# Nearest to more: less, very, most, rather, highly, greater, quite, higher,
# Nearest to people: men, citizens, individuals, women, man, children, jews, persons,
# Nearest to there: they, it, we, sometimes, he, she, now, usually,
# Nearest to system: systems, process, unit, technology, guth, reform, cameroonian, radiant,
# Nearest to over: regarding, within, about, across, mcgrath, dom, around, through,
# Nearest to i: we, you, they, ii, she, ned, gegen, dawkins,
# Nearest to as: xt, like, theresa, chronos, tyrannosaurus, percussion, accumulator, tlc,
# Nearest to also: actually, often, never, now, still, sometimes, usually, generally,
# Nearest to so: too, niro, bmi, rial, beyond, tp, yudhoyono, lusatia,
# Nearest to american: australian, italian, british, irish, polish, african, english, asian,
# Nearest to of: and, in, including, dependant, within, gamete, alleviated, kurds,
# Nearest to its: their, his, her, the, whose, your, our, warmth,
# Nearest to their: its, his, her, your, our, my, the, whose,
# Nearest to it: he, she, there, this, they, itself, superstardom, still,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to when: while, if, before, during, though, after, although, where,
# Average loss at step 82000: 2.664652
# Average loss at step 84000: 2.767349
# Average loss at step 86000: 2.738533
# Average loss at step 88000: 2.754411
# Average loss at step 90000: 2.738730
# Nearest to more: less, most, very, rather, highly, greater, quite, longer,
# Nearest to people: men, women, individuals, citizens, persons, man, children, jews,
# Nearest to there: they, it, he, she, we, sometimes, now, usually,
# Nearest to system: systems, process, reform, unit, cameroonian, radiant, guth, ham,
# Nearest to over: about, across, within, around, off, afesd, regarding, dom,
# Nearest to i: we, you, they, ii, ned, gegen, she, he,
# Nearest to as: theresa, including, like, xt, scottie, hue, vindhya, carmelite,
# Nearest to also: now, never, actually, often, still, which, sometimes, masefield,
# Nearest to so: too, sometimes, bmi, niro, rial, beyond, ozarks, before,
# Nearest to american: australian, italian, british, african, french, polish, asian, offsets,
# Nearest to of: including, teh, shaky, for, grenadines, loo, despite, daylights,
# Nearest to its: their, his, whose, her, the, our, your, negating,
# Nearest to their: its, his, her, your, our, whose, my, browsing,
# Nearest to it: he, she, there, this, they, itself, balanchine, still,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to when: if, before, though, while, where, after, although, because,
# Average loss at step 92000: 2.677893
# Average loss at step 94000: 2.724100
# Average loss at step 96000: 2.702124
# Average loss at step 98000: 2.367415
# Average loss at step 100000: 2.404289
# Nearest to more: less, most, very, rather, smaller, better, quite, faster,
# Nearest to people: men, women, citizens, individuals, children, man, persons, person,
# Nearest to there: they, it, he, she, we, sometimes, still, usually,
# Nearest to system: systems, process, alligators, centrality, unit, reform, catenary, technology,
# Nearest to over: dom, across, off, about, afesd, around, regarding, within,
# Nearest to i: we, ii, you, they, iii, gegen, iv, quarried,
# Nearest to as: after, pham, locksmithing, before, xt, theresa, stockings, zetalisp,
# Nearest to also: actually, now, often, still, never, sometimes, which, already,
# Nearest to so: too, niro, sometimes, thus, bmi, erroneously, lusatia, counterfeiting,
# Nearest to american: australian, english, british, canadian, german, russian, italian, french,
# Nearest to of: in, clears, violates, from, despite, teh, hx, meade,
# Nearest to its: their, his, her, whose, your, our, convenience, the,
# Nearest to their: its, his, her, your, our, my, whose, the,
# Nearest to it: she, he, there, this, itself, still, they, nothing,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to when: if, before, though, after, while, although, where, mujahedeen,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
